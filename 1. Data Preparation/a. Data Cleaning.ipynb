# %%
import pandas as pd
import numpy as np
loan = pd.read_csv('C:/Users/kevin/Documents/HE4045/loan.csv')
pd.set_option('display.max_columns', None)
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_40260\3797189979.py:3: DtypeWarning: Columns (19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan = pd.read_csv('C:/Users/kevin/Documents/HE4045/loan.csv')

# %%
loan.isna().sum()
# Out:
# id                       0
# member_id                0
# loan_amnt                0
# funded_amnt              0
# funded_amnt_inv          0
#                      ...
# all_util            866007
# total_rev_hi_lim     70276
# inq_fi              866007
# total_cu_tl         866007
# inq_last_12m        866007
# Length: 74, dtype: int64

# %%
loan['application_type'].value_counts()
# Out:
# application_type
# INDIVIDUAL    886868
# JOINT            511
# Name: count, dtype: int64

# %%
loan_indv = loan[loan['application_type']=='INDIVIDUAL']

# %%
variables = [
    'annual_inc', 'addr_state', 'delinq_2yrs', 'dti', 'emp_title', 'emp_length', 'funded_amnt', 'grade',
    'home_ownership', 'inq_last_6mths', 'installment', 'int_rate', 'issue_d', 'loan_amnt',
    'loan_status', 'mths_since_last_delinq', 'pub_rec', 'purpose', 'sub_grade', 'term', 'title',
    'total_acc', 'total_pymnt', 'acc_now_delinq'
]

# Select only the columns with selected variables 
loan_indv_cleaned = loan_indv[variables]
loan_indv_cleaned
# Out:
#         annual_inc addr_state  delinq_2yrs    dti  \
# 0          24000.0         AZ          0.0  27.65
# 1          30000.0         GA          0.0   1.00
# 2          12252.0         IL          0.0   8.72
# 3          49200.0         CA          0.0  20.00
# 4          80000.0         OR          0.0  17.94
# ...            ...        ...          ...    ...
# 887374     31000.0         CA          0.0  28.69
# 887375     79000.0         NJ          0.0   3.90
# 887376     35000.0         TN          0.0  30.90
# 887377     64400.0         MA          1.0  27.19
# 887378    100000.0         FL          0.0  10.83
#
#                               emp_title emp_length  funded_amnt grade  \
# 0                                   NaN  10+ years       5000.0     B
# 1                                 Ryder   < 1 year       2500.0     C
# 2                                   NaN  10+ years       2400.0     C
# 3                   AIR RESOURCES BOARD  10+ years      10000.0     C
# 4              University Medical Group     1 year       3000.0     B
# ...                                 ...        ...          ...   ...
# 887374                 Office Assistant    8 years      10000.0     B
# 887375          Director of Maintenance  10+ years      24000.0     B
# 887376         Radiologist Technologist    5 years      13000.0     D
# 887377                          Painter     1 year      12000.0     E
# 887378  Manager Hotel Operations Oasis   10+ years      20000.0     B
#
#        home_ownership  inq_last_6mths  installment  int_rate   issue_d  \
# 0                RENT             1.0       162.87     10.65  Dec-2011
# 1                RENT             5.0        59.83     15.27  Dec-2011
# 2                RENT             2.0        84.33     15.96  Dec-2011
# 3                RENT             1.0       339.31     13.49  Dec-2011
# 4                RENT             0.0        67.79     12.69  Dec-2011
# ...               ...             ...          ...       ...       ...
# 887374           RENT             0.0       332.10     11.99  Jan-2015
# 887375       MORTGAGE             1.0       797.03     11.99  Jan-2015
# 887376           RENT             0.0       316.07     15.99  Jan-2015
# 887377           RENT             2.0       317.86     19.99  Jan-2015
# 887378           RENT             1.0       664.20     11.99  Jan-2015
#
#         loan_amnt  loan_status  mths_since_last_delinq  pub_rec  \
# 0          5000.0   Fully Paid                     NaN      0.0
# 1          2500.0  Charged Off                     NaN      0.0
# 2          2400.0   Fully Paid                     NaN      0.0
# 3         10000.0   Fully Paid                    35.0      0.0
# 4          3000.0      Current                    38.0      0.0
# ...           ...          ...                     ...      ...
# 887374    10000.0      Current                     NaN      1.0
# 887375    24000.0      Current                    26.0      0.0
# 887376    13000.0      Current                     NaN      1.0
# 887377    12000.0      Current                    22.0      0.0
# 887378    20000.0      Current                     NaN      1.0
#
#                    purpose sub_grade        term                    title  \
# 0              credit_card        B2   36 months                 Computer
# 1                      car        C4   60 months                     bike
# 2           small_business        C5   36 months     real estate business
# 3                    other        C1   36 months                 personel
# 4                    other        B5   60 months                 Personal
# ...                    ...       ...         ...                      ...
# 887374  debt_consolidation        B5   36 months       Debt consolidation
# 887375    home_improvement        B5   36 months         Home improvement
# 887376  debt_consolidation        D2   60 months       Debt consolidation
# 887377  debt_consolidation        E3   60 months       Debt consolidation
# 887378         credit_card        B5   36 months  Credit card refinancing
#
#         total_acc   total_pymnt  acc_now_delinq
# 0             9.0   5861.071414             0.0
# 1             4.0   1008.710000             0.0
# 2            10.0   3003.653644             0.0
# 3            37.0  12226.302212             0.0
# 4            38.0   3242.170000             0.0
# ...           ...           ...             ...
# 887374       15.0   3971.880000             0.0
# 887375       23.0   9532.390000             0.0
# 887376       22.0   3769.740000             0.0
# 887377       20.0   3787.670000             0.0
# 887378       10.0   7943.760000             0.0
#
# [886868 rows x 24 columns]

# %%
loan_indv_cleaned['mths_since_last_delinq'] = loan_indv_cleaned['mths_since_last_delinq'].fillna(0)
loan_indv_cleaned
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_40260\2437688461.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_indv_cleaned['mths_since_last_delinq'] = loan_indv_cleaned['mths_since_last_delinq'].fillna(0)
#         annual_inc addr_state  delinq_2yrs    dti  \
# 0          24000.0         AZ          0.0  27.65
# 1          30000.0         GA          0.0   1.00
# 2          12252.0         IL          0.0   8.72
# 3          49200.0         CA          0.0  20.00
# 4          80000.0         OR          0.0  17.94
# ...            ...        ...          ...    ...
# 887374     31000.0         CA          0.0  28.69
# 887375     79000.0         NJ          0.0   3.90
# 887376     35000.0         TN          0.0  30.90
# 887377     64400.0         MA          1.0  27.19
# 887378    100000.0         FL          0.0  10.83
#
#                               emp_title emp_length  funded_amnt grade  \
# 0                                   NaN  10+ years       5000.0     B
# 1                                 Ryder   < 1 year       2500.0     C
# 2                                   NaN  10+ years       2400.0     C
# 3                   AIR RESOURCES BOARD  10+ years      10000.0     C
# 4              University Medical Group     1 year       3000.0     B
# ...                                 ...        ...          ...   ...
# 887374                 Office Assistant    8 years      10000.0     B
# 887375          Director of Maintenance  10+ years      24000.0     B
# 887376         Radiologist Technologist    5 years      13000.0     D
# 887377                          Painter     1 year      12000.0     E
# 887378  Manager Hotel Operations Oasis   10+ years      20000.0     B
#
#        home_ownership  inq_last_6mths  installment  int_rate   issue_d  \
# 0                RENT             1.0       162.87     10.65  Dec-2011
# 1                RENT             5.0        59.83     15.27  Dec-2011
# 2                RENT             2.0        84.33     15.96  Dec-2011
# 3                RENT             1.0       339.31     13.49  Dec-2011
# 4                RENT             0.0        67.79     12.69  Dec-2011
# ...               ...             ...          ...       ...       ...
# 887374           RENT             0.0       332.10     11.99  Jan-2015
# 887375       MORTGAGE             1.0       797.03     11.99  Jan-2015
# 887376           RENT             0.0       316.07     15.99  Jan-2015
# 887377           RENT             2.0       317.86     19.99  Jan-2015
# 887378           RENT             1.0       664.20     11.99  Jan-2015
#
#         loan_amnt  loan_status  mths_since_last_delinq  pub_rec  \
# 0          5000.0   Fully Paid                     0.0      0.0
# 1          2500.0  Charged Off                     0.0      0.0
# 2          2400.0   Fully Paid                     0.0      0.0
# 3         10000.0   Fully Paid                    35.0      0.0
# 4          3000.0      Current                    38.0      0.0
# ...           ...          ...                     ...      ...
# 887374    10000.0      Current                     0.0      1.0
# 887375    24000.0      Current                    26.0      0.0
# 887376    13000.0      Current                     0.0      1.0
# 887377    12000.0      Current                    22.0      0.0
# 887378    20000.0      Current                     0.0      1.0
#
#                    purpose sub_grade        term                    title  \
# 0              credit_card        B2   36 months                 Computer
# 1                      car        C4   60 months                     bike
# 2           small_business        C5   36 months     real estate business
# 3                    other        C1   36 months                 personel
# 4                    other        B5   60 months                 Personal
# ...                    ...       ...         ...                      ...
# 887374  debt_consolidation        B5   36 months       Debt consolidation
# 887375    home_improvement        B5   36 months         Home improvement
# 887376  debt_consolidation        D2   60 months       Debt consolidation
# 887377  debt_consolidation        E3   60 months       Debt consolidation
# 887378         credit_card        B5   36 months  Credit card refinancing
#
#         total_acc   total_pymnt  acc_now_delinq
# 0             9.0   5861.071414             0.0
# 1             4.0   1008.710000             0.0
# 2            10.0   3003.653644             0.0
# 3            37.0  12226.302212             0.0
# 4            38.0   3242.170000             0.0
# ...           ...           ...             ...
# 887374       15.0   3971.880000             0.0
# 887375       23.0   9532.390000             0.0
# 887376       22.0   3769.740000             0.0
# 887377       20.0   3787.670000             0.0
# 887378       10.0   7943.760000             0.0
#
# [886868 rows x 24 columns]

# %%
loan_indv_cleaned.isna().sum()
# Out:
# annual_inc                    4
# addr_state                    0
# delinq_2yrs                  29
# dti                           0
# emp_title                 51401
# emp_length                44764
# funded_amnt                   0
# grade                         0
# home_ownership                0
# inq_last_6mths               29
# installment                   0
# int_rate                      0
# issue_d                       0
# loan_amnt                     0
# loan_status                   0
# mths_since_last_delinq        0
# pub_rec                      29
# purpose                       0
# sub_grade                     0
# term                          0
# title                       144
# total_acc                    29
# total_pymnt                   0
# acc_now_delinq               29
# dtype: int64

# %%
loan_indv_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 886868 entries, 0 to 887378
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   annual_inc              886864 non-null  float64
#  1   addr_state              886868 non-null  object
#  2   delinq_2yrs             886839 non-null  float64
#  3   dti                     886868 non-null  float64
#  4   emp_title               835467 non-null  object
#  5   emp_length              842104 non-null  object
#  6   funded_amnt             886868 non-null  float64
#  7   grade                   886868 non-null  object
#  8   home_ownership          886868 non-null  object
#  9   inq_last_6mths          886839 non-null  float64
#  10  installment             886868 non-null  float64
#  11  int_rate                886868 non-null  float64
#  12  issue_d                 886868 non-null  object
#  13  loan_amnt               886868 non-null  float64
#  14  loan_status             886868 non-null  object
#  15  mths_since_last_delinq  886868 non-null  float64
#  16  pub_rec                 886839 non-null  float64
#  17  purpose                 886868 non-null  object
#  18  sub_grade               886868 non-null  object
#  19  term                    886868 non-null  object
#  20  title                   886724 non-null  object
#  21  total_acc               886839 non-null  float64
#  22  total_pymnt             886868 non-null  float64
#  23  acc_now_delinq          886839 non-null  float64
# dtypes: float64(13), object(11)
# memory usage: 169.2+ MB

# %%
loan_indv_cleaned= loan_indv_cleaned.dropna(subset=['delinq_2yrs'])
loan_indv_cleaned
# Out:
#         annual_inc addr_state  delinq_2yrs    dti  \
# 0          24000.0         AZ          0.0  27.65
# 1          30000.0         GA          0.0   1.00
# 2          12252.0         IL          0.0   8.72
# 3          49200.0         CA          0.0  20.00
# 4          80000.0         OR          0.0  17.94
# ...            ...        ...          ...    ...
# 887374     31000.0         CA          0.0  28.69
# 887375     79000.0         NJ          0.0   3.90
# 887376     35000.0         TN          0.0  30.90
# 887377     64400.0         MA          1.0  27.19
# 887378    100000.0         FL          0.0  10.83
#
#                               emp_title emp_length  funded_amnt grade  \
# 0                                   NaN  10+ years       5000.0     B
# 1                                 Ryder   < 1 year       2500.0     C
# 2                                   NaN  10+ years       2400.0     C
# 3                   AIR RESOURCES BOARD  10+ years      10000.0     C
# 4              University Medical Group     1 year       3000.0     B
# ...                                 ...        ...          ...   ...
# 887374                 Office Assistant    8 years      10000.0     B
# 887375          Director of Maintenance  10+ years      24000.0     B
# 887376         Radiologist Technologist    5 years      13000.0     D
# 887377                          Painter     1 year      12000.0     E
# 887378  Manager Hotel Operations Oasis   10+ years      20000.0     B
#
#        home_ownership  inq_last_6mths  installment  int_rate   issue_d  \
# 0                RENT             1.0       162.87     10.65  Dec-2011
# 1                RENT             5.0        59.83     15.27  Dec-2011
# 2                RENT             2.0        84.33     15.96  Dec-2011
# 3                RENT             1.0       339.31     13.49  Dec-2011
# 4                RENT             0.0        67.79     12.69  Dec-2011
# ...               ...             ...          ...       ...       ...
# 887374           RENT             0.0       332.10     11.99  Jan-2015
# 887375       MORTGAGE             1.0       797.03     11.99  Jan-2015
# 887376           RENT             0.0       316.07     15.99  Jan-2015
# 887377           RENT             2.0       317.86     19.99  Jan-2015
# 887378           RENT             1.0       664.20     11.99  Jan-2015
#
#         loan_amnt  loan_status  mths_since_last_delinq  pub_rec  \
# 0          5000.0   Fully Paid                     0.0      0.0
# 1          2500.0  Charged Off                     0.0      0.0
# 2          2400.0   Fully Paid                     0.0      0.0
# 3         10000.0   Fully Paid                    35.0      0.0
# 4          3000.0      Current                    38.0      0.0
# ...           ...          ...                     ...      ...
# 887374    10000.0      Current                     0.0      1.0
# 887375    24000.0      Current                    26.0      0.0
# 887376    13000.0      Current                     0.0      1.0
# 887377    12000.0      Current                    22.0      0.0
# 887378    20000.0      Current                     0.0      1.0
#
#                    purpose sub_grade        term                    title  \
# 0              credit_card        B2   36 months                 Computer
# 1                      car        C4   60 months                     bike
# 2           small_business        C5   36 months     real estate business
# 3                    other        C1   36 months                 personel
# 4                    other        B5   60 months                 Personal
# ...                    ...       ...         ...                      ...
# 887374  debt_consolidation        B5   36 months       Debt consolidation
# 887375    home_improvement        B5   36 months         Home improvement
# 887376  debt_consolidation        D2   60 months       Debt consolidation
# 887377  debt_consolidation        E3   60 months       Debt consolidation
# 887378         credit_card        B5   36 months  Credit card refinancing
#
#         total_acc   total_pymnt  acc_now_delinq
# 0             9.0   5861.071414             0.0
# 1             4.0   1008.710000             0.0
# 2            10.0   3003.653644             0.0
# 3            37.0  12226.302212             0.0
# 4            38.0   3242.170000             0.0
# ...           ...           ...             ...
# 887374       15.0   3971.880000             0.0
# 887375       23.0   9532.390000             0.0
# 887376       22.0   3769.740000             0.0
# 887377       20.0   3787.670000             0.0
# 887378       10.0   7943.760000             0.0
#
# [886839 rows x 24 columns]

# %%
loan_indv_cleaned.isna().sum()
# Out:
# annual_inc                    0
# addr_state                    0
# delinq_2yrs                   0
# dti                           0
# emp_title                 51389
# emp_length                44764
# funded_amnt                   0
# grade                         0
# home_ownership                0
# inq_last_6mths                0
# installment                   0
# int_rate                      0
# issue_d                       0
# loan_amnt                     0
# loan_status                   0
# mths_since_last_delinq        0
# pub_rec                       0
# purpose                       0
# sub_grade                     0
# term                          0
# title                       144
# total_acc                     0
# total_pymnt                   0
# acc_now_delinq                0
# dtype: int64

# %%
loan_indv_cleaned['emp_length'].value_counts()
# Out:
# emp_length
# 10+ years    291400
# 2 years       78832
# < 1 year      70541
# 3 years       69992
# 1 year        57061
# 5 years       55686
# 4 years       52496
# 7 years       44576
# 8 years       43930
# 6 years       42927
# 9 years       34634
# Name: count, dtype: int64

# %%
loan_indv_cleaned= loan_indv_cleaned.dropna(subset=['emp_length'])
loan_indv_cleaned
# Out:
#         annual_inc addr_state  delinq_2yrs    dti  \
# 0          24000.0         AZ          0.0  27.65
# 1          30000.0         GA          0.0   1.00
# 2          12252.0         IL          0.0   8.72
# 3          49200.0         CA          0.0  20.00
# 4          80000.0         OR          0.0  17.94
# ...            ...        ...          ...    ...
# 887374     31000.0         CA          0.0  28.69
# 887375     79000.0         NJ          0.0   3.90
# 887376     35000.0         TN          0.0  30.90
# 887377     64400.0         MA          1.0  27.19
# 887378    100000.0         FL          0.0  10.83
#
#                               emp_title emp_length  funded_amnt grade  \
# 0                                   NaN  10+ years       5000.0     B
# 1                                 Ryder   < 1 year       2500.0     C
# 2                                   NaN  10+ years       2400.0     C
# 3                   AIR RESOURCES BOARD  10+ years      10000.0     C
# 4              University Medical Group     1 year       3000.0     B
# ...                                 ...        ...          ...   ...
# 887374                 Office Assistant    8 years      10000.0     B
# 887375          Director of Maintenance  10+ years      24000.0     B
# 887376         Radiologist Technologist    5 years      13000.0     D
# 887377                          Painter     1 year      12000.0     E
# 887378  Manager Hotel Operations Oasis   10+ years      20000.0     B
#
#        home_ownership  inq_last_6mths  installment  int_rate   issue_d  \
# 0                RENT             1.0       162.87     10.65  Dec-2011
# 1                RENT             5.0        59.83     15.27  Dec-2011
# 2                RENT             2.0        84.33     15.96  Dec-2011
# 3                RENT             1.0       339.31     13.49  Dec-2011
# 4                RENT             0.0        67.79     12.69  Dec-2011
# ...               ...             ...          ...       ...       ...
# 887374           RENT             0.0       332.10     11.99  Jan-2015
# 887375       MORTGAGE             1.0       797.03     11.99  Jan-2015
# 887376           RENT             0.0       316.07     15.99  Jan-2015
# 887377           RENT             2.0       317.86     19.99  Jan-2015
# 887378           RENT             1.0       664.20     11.99  Jan-2015
#
#         loan_amnt  loan_status  mths_since_last_delinq  pub_rec  \
# 0          5000.0   Fully Paid                     0.0      0.0
# 1          2500.0  Charged Off                     0.0      0.0
# 2          2400.0   Fully Paid                     0.0      0.0
# 3         10000.0   Fully Paid                    35.0      0.0
# 4          3000.0      Current                    38.0      0.0
# ...           ...          ...                     ...      ...
# 887374    10000.0      Current                     0.0      1.0
# 887375    24000.0      Current                    26.0      0.0
# 887376    13000.0      Current                     0.0      1.0
# 887377    12000.0      Current                    22.0      0.0
# 887378    20000.0      Current                     0.0      1.0
#
#                    purpose sub_grade        term                    title  \
# 0              credit_card        B2   36 months                 Computer
# 1                      car        C4   60 months                     bike
# 2           small_business        C5   36 months     real estate business
# 3                    other        C1   36 months                 personel
# 4                    other        B5   60 months                 Personal
# ...                    ...       ...         ...                      ...
# 887374  debt_consolidation        B5   36 months       Debt consolidation
# 887375    home_improvement        B5   36 months         Home improvement
# 887376  debt_consolidation        D2   60 months       Debt consolidation
# 887377  debt_consolidation        E3   60 months       Debt consolidation
# 887378         credit_card        B5   36 months  Credit card refinancing
#
#         total_acc   total_pymnt  acc_now_delinq
# 0             9.0   5861.071414             0.0
# 1             4.0   1008.710000             0.0
# 2            10.0   3003.653644             0.0
# 3            37.0  12226.302212             0.0
# 4            38.0   3242.170000             0.0
# ...           ...           ...             ...
# 887374       15.0   3971.880000             0.0
# 887375       23.0   9532.390000             0.0
# 887376       22.0   3769.740000             0.0
# 887377       20.0   3787.670000             0.0
# 887378       10.0   7943.760000             0.0
#
# [842075 rows x 24 columns]

# %%
loan_indv_cleaned['loan_status'].value_counts()
# Out:
# loan_status
# Current                                                568301
# Fully Paid                                             200350
# Charged Off                                             42723
# Late (31-120 days)                                      10870
# Issued                                                   7769
# In Grace Period                                          6013
# Late (16-30 days)                                        2215
# Does not meet the credit policy. Status:Fully Paid       1943
# Default                                                  1148
# Does not meet the credit policy. Status:Charged Off       743
# Name: count, dtype: int64

# %%
loan_indv_cleaned.isna().sum()
# Out:
# annual_inc                   0
# addr_state                   0
# delinq_2yrs                  0
# dti                          0
# emp_title                 7014
# emp_length                   0
# funded_amnt                  0
# grade                        0
# home_ownership               0
# inq_last_6mths               0
# installment                  0
# int_rate                     0
# issue_d                      0
# loan_amnt                    0
# loan_status                  0
# mths_since_last_delinq       0
# pub_rec                      0
# purpose                      0
# sub_grade                    0
# term                         0
# title                      135
# total_acc                    0
# total_pymnt                  0
# acc_now_delinq               0
# dtype: int64

# %%
loan_indv_cleaned['log_annual_inc'] = np.log(loan_indv_cleaned['annual_inc'])
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_40260\883155574.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_indv_cleaned['log_annual_inc'] = np.log(loan_indv_cleaned['annual_inc'])

# %%
mapping = {
    'Fully Paid': 0,
    'Does not meet the credit policy. Status:Fully Paid': 0,
    'Charged Off': 1,
    'Late (31-120 days)': 1,
    'Default': 1,
    'Does not meet the credit policy. Status:Charged Off': 1
}

# Map the loan status to new values
loan_indv_cleaned['loan_status_grouped'] = loan_indv_cleaned['loan_status'].map(mapping)

# Filter to keep only the relevant statuses (1 and 0)
loan_indv_filtered = loan_indv_cleaned.dropna(subset=['loan_status_grouped'])
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_40260\3805589354.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_indv_cleaned['loan_status_grouped'] = loan_indv_cleaned['loan_status'].map(mapping)

# %%
loan_indv_filtered
# Out:
#         annual_inc addr_state  delinq_2yrs    dti             emp_title  \
# 0          24000.0         AZ          0.0  27.65                   NaN
# 1          30000.0         GA          0.0   1.00                 Ryder
# 2          12252.0         IL          0.0   8.72                   NaN
# 3          49200.0         CA          0.0  20.00   AIR RESOURCES BOARD
# 5          36000.0         AZ          0.0  11.20  Veolia Transportaton
# ...            ...        ...          ...    ...                   ...
# 887347     63078.0         PA          0.0  31.70      customer service
# 887351     48000.0         CO          0.0  36.93            supervisor
# 887364     54000.0         FL          1.0  13.22   Coordinator of RSVP
# 887366     27000.0         FL          0.0  18.58               Painter
# 887369     50000.0         CA          0.0  12.63       Lead Custodian
#
#        emp_length  funded_amnt grade home_ownership  inq_last_6mths  \
# 0       10+ years       5000.0     B           RENT             1.0
# 1        < 1 year       2500.0     C           RENT             5.0
# 2       10+ years       2400.0     C           RENT             2.0
# 3       10+ years      10000.0     C           RENT             1.0
# 5         3 years       5000.0     A           RENT             3.0
# ...           ...          ...   ...            ...             ...
# 887347  10+ years      17000.0     D       MORTGAGE             0.0
# 887351  10+ years       4200.0     D       MORTGAGE             0.0
# 887364   < 1 year      10775.0     A           RENT             0.0
# 887366    2 years       6225.0     D           RENT             1.0
# 887369  10+ years       4000.0     B       MORTGAGE             0.0
#
#         installment  int_rate   issue_d  loan_amnt  loan_status  \
# 0            162.87     10.65  Dec-2011     5000.0   Fully Paid
# 1             59.83     15.27  Dec-2011     2500.0  Charged Off
# 2             84.33     15.96  Dec-2011     2400.0   Fully Paid
# 3            339.31     13.49  Dec-2011    10000.0   Fully Paid
# 5            156.46      7.90  Dec-2011     5000.0   Fully Paid
# ...             ...       ...       ...        ...          ...
# 887347       413.32     15.99  Jan-2015    17000.0   Fully Paid
# 887351       147.64     15.99  Jan-2015     4200.0  Charged Off
# 887364       327.95      6.03  Jan-2015    10775.0   Fully Paid
# 887366       220.37     16.49  Jan-2015     6225.0   Fully Paid
# 887369       126.59      8.67  Jan-2015     4000.0   Fully Paid
#
#         mths_since_last_delinq  pub_rec             purpose sub_grade  \
# 0                          0.0      0.0         credit_card        B2
# 1                          0.0      0.0                 car        C4
# 2                          0.0      0.0      small_business        C5
# 3                         35.0      0.0               other        C1
# 5                          0.0      0.0             wedding        A4
# ...                        ...      ...                 ...       ...
# 887347                     0.0      0.0  debt_consolidation        D2
# 887351                    38.0      0.0             medical        D2
# 887364                    16.0      0.0  debt_consolidation        A1
# 887366                     0.0      0.0  debt_consolidation        D3
# 887369                     0.0      1.0                 car        B1
#
#               term                                  title  total_acc  \
# 0        36 months                               Computer        9.0
# 1        60 months                                   bike        4.0
# 2        36 months                   real estate business       10.0
# 3        36 months                               personel       37.0
# 5        36 months  My wedding loan I promise to pay back       12.0
# ...            ...                                    ...        ...
# 887347   60 months                     Debt consolidation       28.0
# 887351   36 months                       Medical expenses       45.0
# 887364   36 months                     Debt consolidation       21.0
# 887366   36 months                     Debt consolidation        4.0
# 887369   36 months                          Car financing       30.0
#
#          total_pymnt  acc_now_delinq  log_annual_inc  loan_status_grouped
# 0        5861.071414             0.0       10.085809                  0.0
# 1        1008.710000             0.0       10.308953                  1.0
# 2        3003.653644             0.0        9.413444                  0.0
# 3       12226.302212             0.0       10.803649                  0.0
# 5        5631.377753             0.0       10.491274                  0.0
# ...              ...             ...             ...                  ...
# 887347  17196.520000             0.0       11.052127                  0.0
# 887351   1026.020000             0.0       10.778956                  1.0
# 887364  11071.870000             0.0       10.896739                  0.0
# 887366   7050.460000             0.0       10.203592                  0.0
# 887369   4158.020000             0.0       10.819778                  0.0
#
# [257777 rows x 26 columns]

# %%
loan_indv_filtered['loan_status_grouped'].value_counts()
# Out:
# loan_status_grouped
# 0.0    202293
# 1.0     55484
# Name: count, dtype: int64

# %%
loan_indv_filtered
# Out:
#         annual_inc addr_state  delinq_2yrs    dti             emp_title  \
# 0          24000.0         AZ          0.0  27.65                   NaN
# 1          30000.0         GA          0.0   1.00                 Ryder
# 2          12252.0         IL          0.0   8.72                   NaN
# 3          49200.0         CA          0.0  20.00   AIR RESOURCES BOARD
# 5          36000.0         AZ          0.0  11.20  Veolia Transportaton
# ...            ...        ...          ...    ...                   ...
# 887347     63078.0         PA          0.0  31.70      customer service
# 887351     48000.0         CO          0.0  36.93            supervisor
# 887364     54000.0         FL          1.0  13.22   Coordinator of RSVP
# 887366     27000.0         FL          0.0  18.58               Painter
# 887369     50000.0         CA          0.0  12.63       Lead Custodian
#
#        emp_length  funded_amnt grade home_ownership  inq_last_6mths  \
# 0       10+ years       5000.0     B           RENT             1.0
# 1        < 1 year       2500.0     C           RENT             5.0
# 2       10+ years       2400.0     C           RENT             2.0
# 3       10+ years      10000.0     C           RENT             1.0
# 5         3 years       5000.0     A           RENT             3.0
# ...           ...          ...   ...            ...             ...
# 887347  10+ years      17000.0     D       MORTGAGE             0.0
# 887351  10+ years       4200.0     D       MORTGAGE             0.0
# 887364   < 1 year      10775.0     A           RENT             0.0
# 887366    2 years       6225.0     D           RENT             1.0
# 887369  10+ years       4000.0     B       MORTGAGE             0.0
#
#         installment  int_rate   issue_d  loan_amnt  loan_status  \
# 0            162.87     10.65  Dec-2011     5000.0   Fully Paid
# 1             59.83     15.27  Dec-2011     2500.0  Charged Off
# 2             84.33     15.96  Dec-2011     2400.0   Fully Paid
# 3            339.31     13.49  Dec-2011    10000.0   Fully Paid
# 5            156.46      7.90  Dec-2011     5000.0   Fully Paid
# ...             ...       ...       ...        ...          ...
# 887347       413.32     15.99  Jan-2015    17000.0   Fully Paid
# 887351       147.64     15.99  Jan-2015     4200.0  Charged Off
# 887364       327.95      6.03  Jan-2015    10775.0   Fully Paid
# 887366       220.37     16.49  Jan-2015     6225.0   Fully Paid
# 887369       126.59      8.67  Jan-2015     4000.0   Fully Paid
#
#         mths_since_last_delinq  pub_rec             purpose sub_grade  \
# 0                          0.0      0.0         credit_card        B2
# 1                          0.0      0.0                 car        C4
# 2                          0.0      0.0      small_business        C5
# 3                         35.0      0.0               other        C1
# 5                          0.0      0.0             wedding        A4
# ...                        ...      ...                 ...       ...
# 887347                     0.0      0.0  debt_consolidation        D2
# 887351                    38.0      0.0             medical        D2
# 887364                    16.0      0.0  debt_consolidation        A1
# 887366                     0.0      0.0  debt_consolidation        D3
# 887369                     0.0      1.0                 car        B1
#
#               term                                  title  total_acc  \
# 0        36 months                               Computer        9.0
# 1        60 months                                   bike        4.0
# 2        36 months                   real estate business       10.0
# 3        36 months                               personel       37.0
# 5        36 months  My wedding loan I promise to pay back       12.0
# ...            ...                                    ...        ...
# 887347   60 months                     Debt consolidation       28.0
# 887351   36 months                       Medical expenses       45.0
# 887364   36 months                     Debt consolidation       21.0
# 887366   36 months                     Debt consolidation        4.0
# 887369   36 months                          Car financing       30.0
#
#          total_pymnt  acc_now_delinq  log_annual_inc  loan_status_grouped
# 0        5861.071414             0.0       10.085809                  0.0
# 1        1008.710000             0.0       10.308953                  1.0
# 2        3003.653644             0.0        9.413444                  0.0
# 3       12226.302212             0.0       10.803649                  0.0
# 5        5631.377753             0.0       10.491274                  0.0
# ...              ...             ...             ...                  ...
# 887347  17196.520000             0.0       11.052127                  0.0
# 887351   1026.020000             0.0       10.778956                  1.0
# 887364  11071.870000             0.0       10.896739                  0.0
# 887366   7050.460000             0.0       10.203592                  0.0
# 887369   4158.020000             0.0       10.819778                  0.0
#
# [257777 rows x 26 columns]

# %%
loan_indv_filtered.to_csv('cleaned_loan.csv', index=False)
