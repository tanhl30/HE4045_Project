# %%
import pandas as pd
import numpy as np

# %%
loan = pd.read_csv("loan.csv")
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_16500\3592418794.py:1: DtypeWarning: Columns (19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan = pd.read_csv("loan.csv")

# %%
loan.isna().sum()
# Out:
# id                       0
# member_id                0
# loan_amnt                0
# funded_amnt              0
# funded_amnt_inv          0
#                      ...
# all_util            866007
# total_rev_hi_lim     70276
# inq_fi              866007
# total_cu_tl         866007
# inq_last_12m        866007
# Length: 74, dtype: int64

# %%
loan['application_type'].value_counts()
# Out:
# application_type
# INDIVIDUAL    886868
# JOINT            511
# Name: count, dtype: int64

# %%
loan_indv = loan[loan['application_type']=='INDIVIDUAL']

# %%
loan_indv['application_type'].value_counts()
# Out:
# application_type
# INDIVIDUAL    886868
# Name: count, dtype: int64

# %%
regression_Y_columns = [
    'annual_inc', 'delinq_2yrs', 'dti', 'emp_title', 'emp_length', 'funded_amnt', 'grade',
    'home_ownership', 'inq_last_6mths', 'installment', 'int_rate', 'issue_d', 'loan_amnt',
    'loan_status', 'mths_since_last_delinq', 'pub_rec', 'purpose', 'sub_grade', 'term', 'title',
    'total_acc', 'total_pymnt', 'acc_now_delinq'
]

# Select only the columns with Regression = 'Y'
loan_indv_cleaned = loan_indv[regression_Y_columns]
loan_indv_cleaned
# Out:
#         annual_inc  delinq_2yrs    dti                        emp_title  \
# 0          24000.0          0.0  27.65                              NaN
# 1          30000.0          0.0   1.00                            Ryder
# 2          12252.0          0.0   8.72                              NaN
# 3          49200.0          0.0  20.00              AIR RESOURCES BOARD
# 4          80000.0          0.0  17.94         University Medical Group
# ...            ...          ...    ...                              ...
# 887374     31000.0          0.0  28.69                 Office Assistant
# 887375     79000.0          0.0   3.90          Director of Maintenance
# 887376     35000.0          0.0  30.90         Radiologist Technologist
# 887377     64400.0          1.0  27.19                          Painter
# 887378    100000.0          0.0  10.83  Manager Hotel Operations Oasis
#
#        emp_length  funded_amnt grade home_ownership  inq_last_6mths  \
# 0       10+ years       5000.0     B           RENT             1.0
# 1        < 1 year       2500.0     C           RENT             5.0
# 2       10+ years       2400.0     C           RENT             2.0
# 3       10+ years      10000.0     C           RENT             1.0
# 4          1 year       3000.0     B           RENT             0.0
# ...           ...          ...   ...            ...             ...
# 887374    8 years      10000.0     B           RENT             0.0
# 887375  10+ years      24000.0     B       MORTGAGE             1.0
# 887376    5 years      13000.0     D           RENT             0.0
# 887377     1 year      12000.0     E           RENT             2.0
# 887378  10+ years      20000.0     B           RENT             1.0
#
#         installment  ...  loan_status mths_since_last_delinq  pub_rec  \
# 0            162.87  ...   Fully Paid                    NaN      0.0
# 1             59.83  ...  Charged Off                    NaN      0.0
# 2             84.33  ...   Fully Paid                    NaN      0.0
# 3            339.31  ...   Fully Paid                   35.0      0.0
# 4             67.79  ...      Current                   38.0      0.0
# ...             ...  ...          ...                    ...      ...
# 887374       332.10  ...      Current                    NaN      1.0
# 887375       797.03  ...      Current                   26.0      0.0
# 887376       316.07  ...      Current                    NaN      1.0
# 887377       317.86  ...      Current                   22.0      0.0
# 887378       664.20  ...      Current                    NaN      1.0
#
#                    purpose  sub_grade        term                    title  \
# 0              credit_card         B2   36 months                 Computer
# 1                      car         C4   60 months                     bike
# 2           small_business         C5   36 months     real estate business
# 3                    other         C1   36 months                 personel
# 4                    other         B5   60 months                 Personal
# ...                    ...        ...         ...                      ...
# 887374  debt_consolidation         B5   36 months       Debt consolidation
# 887375    home_improvement         B5   36 months         Home improvement
# 887376  debt_consolidation         D2   60 months       Debt consolidation
# 887377  debt_consolidation         E3   60 months       Debt consolidation
# 887378         credit_card         B5   36 months  Credit card refinancing
#
#        total_acc   total_pymnt acc_now_delinq
# 0            9.0   5861.071414            0.0
# 1            4.0   1008.710000            0.0
# 2           10.0   3003.653644            0.0
# 3           37.0  12226.302212            0.0
# 4           38.0   3242.170000            0.0
# ...          ...           ...            ...
# 887374      15.0   3971.880000            0.0
# 887375      23.0   9532.390000            0.0
# 887376      22.0   3769.740000            0.0
# 887377      20.0   3787.670000            0.0
# 887378      10.0   7943.760000            0.0
#
# [886868 rows x 23 columns]

# %%
loan_indv_cleaned['mths_since_last_delinq'] = loan_indv_cleaned['mths_since_last_delinq'].fillna(0)
loan_indv_cleaned
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_16500\2437688461.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_indv_cleaned['mths_since_last_delinq'] = loan_indv_cleaned['mths_since_last_delinq'].fillna(0)
#         annual_inc  delinq_2yrs    dti                        emp_title  \
# 0          24000.0          0.0  27.65                              NaN
# 1          30000.0          0.0   1.00                            Ryder
# 2          12252.0          0.0   8.72                              NaN
# 3          49200.0          0.0  20.00              AIR RESOURCES BOARD
# 4          80000.0          0.0  17.94         University Medical Group
# ...            ...          ...    ...                              ...
# 887374     31000.0          0.0  28.69                 Office Assistant
# 887375     79000.0          0.0   3.90          Director of Maintenance
# 887376     35000.0          0.0  30.90         Radiologist Technologist
# 887377     64400.0          1.0  27.19                          Painter
# 887378    100000.0          0.0  10.83  Manager Hotel Operations Oasis
#
#        emp_length  funded_amnt grade home_ownership  inq_last_6mths  \
# 0       10+ years       5000.0     B           RENT             1.0
# 1        < 1 year       2500.0     C           RENT             5.0
# 2       10+ years       2400.0     C           RENT             2.0
# 3       10+ years      10000.0     C           RENT             1.0
# 4          1 year       3000.0     B           RENT             0.0
# ...           ...          ...   ...            ...             ...
# 887374    8 years      10000.0     B           RENT             0.0
# 887375  10+ years      24000.0     B       MORTGAGE             1.0
# 887376    5 years      13000.0     D           RENT             0.0
# 887377     1 year      12000.0     E           RENT             2.0
# 887378  10+ years      20000.0     B           RENT             1.0
#
#         installment  ...  loan_status mths_since_last_delinq  pub_rec  \
# 0            162.87  ...   Fully Paid                    0.0      0.0
# 1             59.83  ...  Charged Off                    0.0      0.0
# 2             84.33  ...   Fully Paid                    0.0      0.0
# 3            339.31  ...   Fully Paid                   35.0      0.0
# 4             67.79  ...      Current                   38.0      0.0
# ...             ...  ...          ...                    ...      ...
# 887374       332.10  ...      Current                    0.0      1.0
# 887375       797.03  ...      Current                   26.0      0.0
# 887376       316.07  ...      Current                    0.0      1.0
# 887377       317.86  ...      Current                   22.0      0.0
# 887378       664.20  ...      Current                    0.0      1.0
#
#                    purpose  sub_grade        term                    title  \
# 0              credit_card         B2   36 months                 Computer
# 1                      car         C4   60 months                     bike
# 2           small_business         C5   36 months     real estate business
# 3                    other         C1   36 months                 personel
# 4                    other         B5   60 months                 Personal
# ...                    ...        ...         ...                      ...
# 887374  debt_consolidation         B5   36 months       Debt consolidation
# 887375    home_improvement         B5   36 months         Home improvement
# 887376  debt_consolidation         D2   60 months       Debt consolidation
# 887377  debt_consolidation         E3   60 months       Debt consolidation
# 887378         credit_card         B5   36 months  Credit card refinancing
#
#        total_acc   total_pymnt acc_now_delinq
# 0            9.0   5861.071414            0.0
# 1            4.0   1008.710000            0.0
# 2           10.0   3003.653644            0.0
# 3           37.0  12226.302212            0.0
# 4           38.0   3242.170000            0.0
# ...          ...           ...            ...
# 887374      15.0   3971.880000            0.0
# 887375      23.0   9532.390000            0.0
# 887376      22.0   3769.740000            0.0
# 887377      20.0   3787.670000            0.0
# 887378      10.0   7943.760000            0.0
#
# [886868 rows x 23 columns]

# %%
loan_indv_cleaned.isna().sum()
# Out:
# annual_inc                    4
# delinq_2yrs                  29
# dti                           0
# emp_title                 51401
# emp_length                44764
# funded_amnt                   0
# grade                         0
# home_ownership                0
# inq_last_6mths               29
# installment                   0
# int_rate                      0
# issue_d                       0
# loan_amnt                     0
# loan_status                   0
# mths_since_last_delinq        0
# pub_rec                      29
# purpose                       0
# sub_grade                     0
# term                          0
# title                       144
# total_acc                    29
# total_pymnt                   0
# acc_now_delinq               29
# dtype: int64

# %%
loan_indv_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 886868 entries, 0 to 887378
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   annual_inc              886864 non-null  float64
#  1   delinq_2yrs             886839 non-null  float64
#  2   dti                     886868 non-null  float64
#  3   emp_title               835467 non-null  object
#  4   emp_length              842104 non-null  object
#  5   funded_amnt             886868 non-null  float64
#  6   grade                   886868 non-null  object
#  7   home_ownership          886868 non-null  object
#  8   inq_last_6mths          886839 non-null  float64
#  9   installment             886868 non-null  float64
#  10  int_rate                886868 non-null  float64
#  11  issue_d                 886868 non-null  object
#  12  loan_amnt               886868 non-null  float64
#  13  loan_status             886868 non-null  object
#  14  mths_since_last_delinq  886868 non-null  float64
#  15  pub_rec                 886839 non-null  float64
#  16  purpose                 886868 non-null  object
#  17  sub_grade               886868 non-null  object
#  18  term                    886868 non-null  object
#  19  title                   886724 non-null  object
#  20  total_acc               886839 non-null  float64
#  21  total_pymnt             886868 non-null  float64
#  22  acc_now_delinq          886839 non-null  float64
# dtypes: float64(13), object(10)
# memory usage: 162.4+ MB

# %%
loan_indv_cleaned= loan_indv_cleaned.dropna(subset=['delinq_2yrs'])
loan_indv_cleaned
# Out:
#         annual_inc  delinq_2yrs    dti                        emp_title  \
# 0          24000.0          0.0  27.65                              NaN
# 1          30000.0          0.0   1.00                            Ryder
# 2          12252.0          0.0   8.72                              NaN
# 3          49200.0          0.0  20.00              AIR RESOURCES BOARD
# 4          80000.0          0.0  17.94         University Medical Group
# ...            ...          ...    ...                              ...
# 887374     31000.0          0.0  28.69                 Office Assistant
# 887375     79000.0          0.0   3.90          Director of Maintenance
# 887376     35000.0          0.0  30.90         Radiologist Technologist
# 887377     64400.0          1.0  27.19                          Painter
# 887378    100000.0          0.0  10.83  Manager Hotel Operations Oasis
#
#        emp_length  funded_amnt grade home_ownership  inq_last_6mths  \
# 0       10+ years       5000.0     B           RENT             1.0
# 1        < 1 year       2500.0     C           RENT             5.0
# 2       10+ years       2400.0     C           RENT             2.0
# 3       10+ years      10000.0     C           RENT             1.0
# 4          1 year       3000.0     B           RENT             0.0
# ...           ...          ...   ...            ...             ...
# 887374    8 years      10000.0     B           RENT             0.0
# 887375  10+ years      24000.0     B       MORTGAGE             1.0
# 887376    5 years      13000.0     D           RENT             0.0
# 887377     1 year      12000.0     E           RENT             2.0
# 887378  10+ years      20000.0     B           RENT             1.0
#
#         installment  ...  loan_status mths_since_last_delinq  pub_rec  \
# 0            162.87  ...   Fully Paid                    0.0      0.0
# 1             59.83  ...  Charged Off                    0.0      0.0
# 2             84.33  ...   Fully Paid                    0.0      0.0
# 3            339.31  ...   Fully Paid                   35.0      0.0
# 4             67.79  ...      Current                   38.0      0.0
# ...             ...  ...          ...                    ...      ...
# 887374       332.10  ...      Current                    0.0      1.0
# 887375       797.03  ...      Current                   26.0      0.0
# 887376       316.07  ...      Current                    0.0      1.0
# 887377       317.86  ...      Current                   22.0      0.0
# 887378       664.20  ...      Current                    0.0      1.0
#
#                    purpose  sub_grade        term                    title  \
# 0              credit_card         B2   36 months                 Computer
# 1                      car         C4   60 months                     bike
# 2           small_business         C5   36 months     real estate business
# 3                    other         C1   36 months                 personel
# 4                    other         B5   60 months                 Personal
# ...                    ...        ...         ...                      ...
# 887374  debt_consolidation         B5   36 months       Debt consolidation
# 887375    home_improvement         B5   36 months         Home improvement
# 887376  debt_consolidation         D2   60 months       Debt consolidation
# 887377  debt_consolidation         E3   60 months       Debt consolidation
# 887378         credit_card         B5   36 months  Credit card refinancing
#
#        total_acc   total_pymnt acc_now_delinq
# 0            9.0   5861.071414            0.0
# 1            4.0   1008.710000            0.0
# 2           10.0   3003.653644            0.0
# 3           37.0  12226.302212            0.0
# 4           38.0   3242.170000            0.0
# ...          ...           ...            ...
# 887374      15.0   3971.880000            0.0
# 887375      23.0   9532.390000            0.0
# 887376      22.0   3769.740000            0.0
# 887377      20.0   3787.670000            0.0
# 887378      10.0   7943.760000            0.0
#
# [886839 rows x 23 columns]

# %%
loan_indv_cleaned.isna().sum()
# Out:
# annual_inc                    0
# delinq_2yrs                   0
# dti                           0
# emp_title                 51389
# emp_length                44764
# funded_amnt                   0
# grade                         0
# home_ownership                0
# inq_last_6mths                0
# installment                   0
# int_rate                      0
# issue_d                       0
# loan_amnt                     0
# loan_status                   0
# mths_since_last_delinq        0
# pub_rec                       0
# purpose                       0
# sub_grade                     0
# term                          0
# title                       144
# total_acc                     0
# total_pymnt                   0
# acc_now_delinq                0
# dtype: int64

# %%
loan_indv_cleaned['emp_length'].value_counts()
# Out:
# emp_length
# 10+ years    291400
# 2 years       78832
# < 1 year      70541
# 3 years       69992
# 1 year        57061
# 5 years       55686
# 4 years       52496
# 7 years       44576
# 8 years       43930
# 6 years       42927
# 9 years       34634
# Name: count, dtype: int64

# %%
loan_indv_cleaned[loan_indv_cleaned['emp_length'].isna()]
# Out:
#         annual_inc  delinq_2yrs    dti emp_title emp_length  funded_amnt  \
# 168        12000.0          0.0  16.30       NaN        NaN       2500.0
# 323        60000.0          0.0  21.96       NaN        NaN      18000.0
# 394        24000.0          1.0   7.50       NaN        NaN       4000.0
# 422        18408.0          0.0   6.00       NaN        NaN       1000.0
# 439        31500.0          0.0  17.87       NaN        NaN       8250.0
# ...            ...          ...    ...       ...        ...          ...
# 887321     62000.0          0.0   8.82       NaN        NaN      20000.0
# 887337     49000.0          1.0  22.58       NaN        NaN      19600.0
# 887355     54000.0          0.0  18.11       NaN        NaN      26950.0
# 887359     55000.0          0.0   5.52       NaN        NaN      25000.0
# 887371     32000.0          0.0  29.44       NaN        NaN      10850.0
#
#        grade home_ownership  inq_last_6mths  installment  ...  \
# 168        A            OWN             2.0        77.78  ...
# 323        D       MORTGAGE             1.0       452.98  ...
# 394        B           RENT             0.0       132.31  ...
# 422        C           RENT             2.0        34.50  ...
# 439        A       MORTGAGE             4.0       256.67  ...
# ...      ...            ...             ...          ...  ...
# 887321     B       MORTGAGE             0.0       411.98  ...
# 887337     C            OWN             2.0       459.22  ...
# 887355     A           RENT             0.0       846.88  ...
# 887359     D            OWN             0.0       602.52  ...
# 887371     E            OWN             1.0       399.04  ...
#
#                loan_status mths_since_last_delinq  pub_rec  \
# 168            Charged Off                    0.0      0.0
# 323             Fully Paid                   75.0      0.0
# 394             Fully Paid                   16.0      0.0
# 422            Charged Off                    0.0      1.0
# 439             Fully Paid                    0.0      0.0
# ...                    ...                    ...      ...
# 887321             Current                    0.0      0.0
# 887337  Late (31-120 days)                    6.0      0.0
# 887355             Current                    0.0      0.0
# 887359             Current                    0.0      0.0
# 887371         Charged Off                   65.0      0.0
#
#                    purpose  sub_grade        term                       title  \
# 168     debt_consolidation         A3   36 months            GET FREE OF DEBT
# 323     debt_consolidation         D4   60 months               consolidation
# 394       home_improvement         B3   36 months  Reline pool and fix steeps
# 422         major_purchase         C3   36 months                      Myloan
# 439     debt_consolidation         A3   36 months                     do over
# ...                    ...        ...         ...                         ...
# 887321         credit_card         B1   60 months     Credit card refinancing
# 887337         credit_card         C4   60 months     Credit card refinancing
# 887355  debt_consolidation         A5   36 months          Debt consolidation
# 887359  debt_consolidation         D1   60 months          Debt consolidation
# 887371  debt_consolidation         E2   36 months          Debt consolidation
#
#        total_acc   total_pymnt acc_now_delinq
# 168         20.0   1838.880000            0.0
# 323         28.0  26369.525524            0.0
# 394          6.0   4185.930000            0.0
# 422          8.0     91.310000            0.0
# 439         37.0   9236.369059            0.0
# ...          ...           ...            ...
# 887321      25.0   4934.130000            0.0
# 887337      48.0   4064.940000            0.0
# 887355      28.0  10138.040000            0.0
# 887359      26.0   7186.930000            0.0
# 887371      20.0   2396.050000            0.0
#
# [44764 rows x 23 columns]

# %%
loan_indv_cleaned= loan_indv_cleaned.dropna(subset=['emp_length'])
loan_indv_cleaned
# Out:
#         annual_inc  delinq_2yrs    dti                        emp_title  \
# 0          24000.0          0.0  27.65                              NaN
# 1          30000.0          0.0   1.00                            Ryder
# 2          12252.0          0.0   8.72                              NaN
# 3          49200.0          0.0  20.00              AIR RESOURCES BOARD
# 4          80000.0          0.0  17.94         University Medical Group
# ...            ...          ...    ...                              ...
# 887374     31000.0          0.0  28.69                 Office Assistant
# 887375     79000.0          0.0   3.90          Director of Maintenance
# 887376     35000.0          0.0  30.90         Radiologist Technologist
# 887377     64400.0          1.0  27.19                          Painter
# 887378    100000.0          0.0  10.83  Manager Hotel Operations Oasis
#
#        emp_length  funded_amnt grade home_ownership  inq_last_6mths  \
# 0       10+ years       5000.0     B           RENT             1.0
# 1        < 1 year       2500.0     C           RENT             5.0
# 2       10+ years       2400.0     C           RENT             2.0
# 3       10+ years      10000.0     C           RENT             1.0
# 4          1 year       3000.0     B           RENT             0.0
# ...           ...          ...   ...            ...             ...
# 887374    8 years      10000.0     B           RENT             0.0
# 887375  10+ years      24000.0     B       MORTGAGE             1.0
# 887376    5 years      13000.0     D           RENT             0.0
# 887377     1 year      12000.0     E           RENT             2.0
# 887378  10+ years      20000.0     B           RENT             1.0
#
#         installment  ...  loan_status mths_since_last_delinq  pub_rec  \
# 0            162.87  ...   Fully Paid                    0.0      0.0
# 1             59.83  ...  Charged Off                    0.0      0.0
# 2             84.33  ...   Fully Paid                    0.0      0.0
# 3            339.31  ...   Fully Paid                   35.0      0.0
# 4             67.79  ...      Current                   38.0      0.0
# ...             ...  ...          ...                    ...      ...
# 887374       332.10  ...      Current                    0.0      1.0
# 887375       797.03  ...      Current                   26.0      0.0
# 887376       316.07  ...      Current                    0.0      1.0
# 887377       317.86  ...      Current                   22.0      0.0
# 887378       664.20  ...      Current                    0.0      1.0
#
#                    purpose  sub_grade        term                    title  \
# 0              credit_card         B2   36 months                 Computer
# 1                      car         C4   60 months                     bike
# 2           small_business         C5   36 months     real estate business
# 3                    other         C1   36 months                 personel
# 4                    other         B5   60 months                 Personal
# ...                    ...        ...         ...                      ...
# 887374  debt_consolidation         B5   36 months       Debt consolidation
# 887375    home_improvement         B5   36 months         Home improvement
# 887376  debt_consolidation         D2   60 months       Debt consolidation
# 887377  debt_consolidation         E3   60 months       Debt consolidation
# 887378         credit_card         B5   36 months  Credit card refinancing
#
#        total_acc   total_pymnt acc_now_delinq
# 0            9.0   5861.071414            0.0
# 1            4.0   1008.710000            0.0
# 2           10.0   3003.653644            0.0
# 3           37.0  12226.302212            0.0
# 4           38.0   3242.170000            0.0
# ...          ...           ...            ...
# 887374      15.0   3971.880000            0.0
# 887375      23.0   9532.390000            0.0
# 887376      22.0   3769.740000            0.0
# 887377      20.0   3787.670000            0.0
# 887378      10.0   7943.760000            0.0
#
# [842075 rows x 23 columns]

# %%
loan_indv_cleaned['loan_status'].value_counts()
# Out:
# loan_status
# Current                                                568301
# Fully Paid                                             200350
# Charged Off                                             42723
# Late (31-120 days)                                      10870
# Issued                                                   7769
# In Grace Period                                          6013
# Late (16-30 days)                                        2215
# Does not meet the credit policy. Status:Fully Paid       1943
# Default                                                  1148
# Does not meet the credit policy. Status:Charged Off       743
# Name: count, dtype: int64

# %%
loan_indv_cleaned.isna().sum()
# Out:
# annual_inc                   0
# delinq_2yrs                  0
# dti                          0
# emp_title                 7014
# emp_length                   0
# funded_amnt                  0
# grade                        0
# home_ownership               0
# inq_last_6mths               0
# installment                  0
# int_rate                     0
# issue_d                      0
# loan_amnt                    0
# loan_status                  0
# mths_since_last_delinq       0
# pub_rec                      0
# purpose                      0
# sub_grade                    0
# term                         0
# title                      135
# total_acc                    0
# total_pymnt                  0
# acc_now_delinq               0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np

# %%
loan_indv_cleaned['log_annual_inc'] = np.log(loan_indv_cleaned['annual_inc'])
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_16500\883155574.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_indv_cleaned['log_annual_inc'] = np.log(loan_indv_cleaned['annual_inc'])

# %%
# 1. Basic Information about the Dataset
print("Basic Info:")
print(loan_indv_cleaned.info())
print("\nSummary Statistics:")
print(loan_indv_cleaned.describe())

# 2. Check for Missing Values
print("\nMissing Values:")
print(loan_indv_cleaned.isnull().sum())

# 3. Distribution of Numerical Features
plt.figure(figsize=(15, 10))
#loan_indv_cleaned[np.log(loan_indv_cleaned['annual_inc'])].hist(bins=100, figsize=(15, 10))
loan_indv_cleaned.hist(bins=100, figsize=(15, 10))
plt.tight_layout()
plt.show()
# Out:
# Basic Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842075 entries, 0 to 887378
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   annual_inc              842075 non-null  float64
#  1   delinq_2yrs             842075 non-null  float64
#  2   dti                     842075 non-null  float64
#  3   emp_title               835061 non-null  object
#  4   emp_length              842075 non-null  object
#  5   funded_amnt             842075 non-null  float64
#  6   grade                   842075 non-null  object
#  7   home_ownership          842075 non-null  object
#  8   inq_last_6mths          842075 non-null  float64
#  9   installment             842075 non-null  float64
#  10  int_rate                842075 non-null  float64
#  11  issue_d                 842075 non-null  object
#  12  loan_amnt               842075 non-null  float64
#  13  loan_status             842075 non-null  object
#  14  mths_since_last_delinq  842075 non-null  float64
#  15  pub_rec                 842075 non-null  float64
#  16  purpose                 842075 non-null  object
#  17  sub_grade               842075 non-null  object
#  18  term                    842075 non-null  object
#  19  title                   841940 non-null  object
#  20  total_acc               842075 non-null  float64
#  21  total_pymnt             842075 non-null  float64
#  22  acc_now_delinq          842075 non-null  float64
#  23  log_annual_inc          842075 non-null  float64
# dtypes: float64(14), object(10)
# memory usage: 160.6+ MB
# None
#
# Summary Statistics:
#          annual_inc    delinq_2yrs            dti    funded_amnt  \
# count  8.420750e+05  842075.000000  842075.000000  842075.000000
# mean   7.636096e+04       0.317313      18.053772   14897.497165
# std    6.565492e+04       0.866132       8.261000    8443.589602
# min    1.896000e+03       0.000000       0.000000     500.000000
# 25%    4.700000e+04       0.000000      11.870000    8325.000000
# 50%    6.500000e+04       0.000000      17.580000   13200.000000
# 75%    9.000000e+04       0.000000      23.830000   20000.000000
# max    9.500000e+06      39.000000      39.990000   35000.000000
#
#        inq_last_6mths    installment       int_rate      loan_amnt  \
# count   842075.000000  842075.000000  842075.000000  842075.000000
# mean         0.696265     440.682446      13.244268   14911.355194
# std          1.000695     244.637679       4.385644    8449.079757
# min          0.000000      15.670000       5.320000     500.000000
# 25%          0.000000     263.930000       9.990000    8325.000000
# 50%          0.000000     386.640000      12.990000   13200.000000
# 75%          1.000000     577.440000      16.200000   20000.000000
# max         33.000000    1445.460000      28.990000   35000.000000
#
#        mths_since_last_delinq        pub_rec      total_acc    total_pymnt  \
# count           842075.000000  842075.000000  842075.000000  842075.000000
# mean                16.572150       0.188894      25.336841    7679.066294
# std                 22.826647       0.576388      11.845600    7935.703012
# min                  0.000000       0.000000       1.000000       0.000000
# 25%                  0.000000       0.000000      17.000000    1967.950000
# 50%                  0.000000       0.000000      24.000000    5012.790000
# 75%                 30.000000       0.000000      32.000000   10799.240000
# max                188.000000      86.000000     169.000000   57777.579870
#
#        acc_now_delinq  log_annual_inc
# count   842075.000000   842075.000000
# mean         0.005011       11.097093
# std          0.077815        0.516940
# min          0.000000        7.547502
# 25%          0.000000       10.757903
# 50%          0.000000       11.082143
# 75%          0.000000       11.407565
# max         14.000000       16.066802
#
# Missing Values:
# annual_inc                   0
# delinq_2yrs                  0
# dti                          0
# emp_title                 7014
# emp_length                   0
# funded_amnt                  0
# grade                        0
# home_ownership               0
# inq_last_6mths               0
# installment                  0
# int_rate                     0
# issue_d                      0
# loan_amnt                    0
# loan_status                  0
# mths_since_last_delinq       0
# pub_rec                      0
# purpose                      0
# sub_grade                    0
# term                         0
# title                      135
# total_acc                    0
# total_pymnt                  0
# acc_now_delinq               0
# log_annual_inc               0
# dtype: int64

# %%
# 4. Distribution of Categorical Features
categorical_columns = loan_indv_cleaned.select_dtypes(include=['object']).columns

for col in categorical_columns:
    plt.figure(figsize=(10, 5))
    sns.countplot(x=col, data=loan_indv_cleaned)
    plt.xticks(rotation=45)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
# 5. Correlation Heatmap for Numerical Features
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
# 6. Boxplots for Numerical Features (to check for outliers)
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns

for col in numerical_columns:
    plt.figure(figsize=(10, 5))
    sns.boxplot(x=loan_indv_cleaned[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
# 7. Pairplot for Relationships between Features (optional, for small datasets)
sns.pairplot(loan_indv_cleaned)
plt.show()

# %%
mapping = {
    'Fully Paid': 1,
    'Does not meet the credit policy. Status:Fully Paid': 1,
    'Charged Off': 0,
    'Late (31-120 days)': 0,
    'Does not meet the credit policy. Status:Charged Off': 0
}

# Map the loan status to new values
loan_indv_cleaned['loan_status_grouped'] = loan_indv_cleaned['loan_status'].map(mapping)

# Filter to keep only the relevant statuses (1 and 0)
loan_indv_filtered = loan_indv_cleaned.dropna(subset=['loan_status_grouped'])
# Out:
# C:\Users\kevin\AppData\Local\Temp\ipykernel_16500\2208445675.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_indv_cleaned['loan_status_grouped'] = loan_indv_cleaned['loan_status'].map(mapping)

# %%
loan_indv_cleaned["loan_status"].value_counts()
# Out:
# loan_status
# Current                                                568301
# Fully Paid                                             200350
# Charged Off                                             42723
# Late (31-120 days)                                      10870
# Issued                                                   7769
# In Grace Period                                          6013
# Late (16-30 days)                                        2215
# Does not meet the credit policy. Status:Fully Paid       1943
# Default                                                  1148
# Does not meet the credit policy. Status:Charged Off       743
# Name: count, dtype: int64

# %%
pd.set_option('display.max_columns', None)

# %%
loan_indv_filtered
# Out:
#         annual_inc  delinq_2yrs    dti             emp_title emp_length  \
# 0          24000.0          0.0  27.65                   NaN  10+ years
# 1          30000.0          0.0   1.00                 Ryder   < 1 year
# 2          12252.0          0.0   8.72                   NaN  10+ years
# 3          49200.0          0.0  20.00   AIR RESOURCES BOARD  10+ years
# 5          36000.0          0.0  11.20  Veolia Transportaton    3 years
# ...            ...          ...    ...                   ...        ...
# 887347     63078.0          0.0  31.70      customer service  10+ years
# 887351     48000.0          0.0  36.93            supervisor  10+ years
# 887364     54000.0          1.0  13.22   Coordinator of RSVP   < 1 year
# 887366     27000.0          0.0  18.58               Painter    2 years
# 887369     50000.0          0.0  12.63       Lead Custodian   10+ years
#
#         funded_amnt grade home_ownership  inq_last_6mths  installment  \
# 0            5000.0     B           RENT             1.0       162.87
# 1            2500.0     C           RENT             5.0        59.83
# 2            2400.0     C           RENT             2.0        84.33
# 3           10000.0     C           RENT             1.0       339.31
# 5            5000.0     A           RENT             3.0       156.46
# ...             ...   ...            ...             ...          ...
# 887347      17000.0     D       MORTGAGE             0.0       413.32
# 887351       4200.0     D       MORTGAGE             0.0       147.64
# 887364      10775.0     A           RENT             0.0       327.95
# 887366       6225.0     D           RENT             1.0       220.37
# 887369       4000.0     B       MORTGAGE             0.0       126.59
#
#         int_rate   issue_d  loan_amnt  loan_status  mths_since_last_delinq  \
# 0          10.65  Dec-2011     5000.0   Fully Paid                     0.0
# 1          15.27  Dec-2011     2500.0  Charged Off                     0.0
# 2          15.96  Dec-2011     2400.0   Fully Paid                     0.0
# 3          13.49  Dec-2011    10000.0   Fully Paid                    35.0
# 5           7.90  Dec-2011     5000.0   Fully Paid                     0.0
# ...          ...       ...        ...          ...                     ...
# 887347     15.99  Jan-2015    17000.0   Fully Paid                     0.0
# 887351     15.99  Jan-2015     4200.0  Charged Off                    38.0
# 887364      6.03  Jan-2015    10775.0   Fully Paid                    16.0
# 887366     16.49  Jan-2015     6225.0   Fully Paid                     0.0
# 887369      8.67  Jan-2015     4000.0   Fully Paid                     0.0
#
#         pub_rec             purpose sub_grade        term  \
# 0           0.0         credit_card        B2   36 months
# 1           0.0                 car        C4   60 months
# 2           0.0      small_business        C5   36 months
# 3           0.0               other        C1   36 months
# 5           0.0             wedding        A4   36 months
# ...         ...                 ...       ...         ...
# 887347      0.0  debt_consolidation        D2   60 months
# 887351      0.0             medical        D2   36 months
# 887364      0.0  debt_consolidation        A1   36 months
# 887366      0.0  debt_consolidation        D3   36 months
# 887369      1.0                 car        B1   36 months
#
#                                         title  total_acc   total_pymnt  \
# 0                                    Computer        9.0   5861.071414
# 1                                        bike        4.0   1008.710000
# 2                        real estate business       10.0   3003.653644
# 3                                    personel       37.0  12226.302212
# 5       My wedding loan I promise to pay back       12.0   5631.377753
# ...                                       ...        ...           ...
# 887347                     Debt consolidation       28.0  17196.520000
# 887351                       Medical expenses       45.0   1026.020000
# 887364                     Debt consolidation       21.0  11071.870000
# 887366                     Debt consolidation        4.0   7050.460000
# 887369                          Car financing       30.0   4158.020000
#
#         acc_now_delinq  log_annual_inc  loan_status_grouped
# 0                  0.0       10.085809                  1.0
# 1                  0.0       10.308953                  0.0
# 2                  0.0        9.413444                  1.0
# 3                  0.0       10.803649                  1.0
# 5                  0.0       10.491274                  1.0
# ...                ...             ...                  ...
# 887347             0.0       11.052127                  1.0
# 887351             0.0       10.778956                  0.0
# 887364             0.0       10.896739                  1.0
# 887366             0.0       10.203592                  1.0
# 887369             0.0       10.819778                  1.0
#
# [256629 rows x 25 columns]

# %%
loan_indv_filtered['loan_status_grouped'].value_counts()
# Out:
# loan_status_grouped
# 1.0    202293
# 0.0     54336
# Name: count, dtype: int64

# %%
loan_indv_filtered.to_csv('output.csv', index=False)
